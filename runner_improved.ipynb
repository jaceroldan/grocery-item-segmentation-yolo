# %%
import os
# no nvlink
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
# use a specific GPU
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3,4,5,6,7"

# %% [markdown]
# # Trial 10-11: Run MixUp Variation
#
# With epochs 30 and epochs 50.

# %% [markdown]
# ## Epochs: 30

# %%
# !yolo task=segment mode=train model=yolo11x-seg.pt data=config.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.015 hsv_s=0.7 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=256 device=0,1,2,3,4,5,6,7
# Out:
# New https://pypi.org/project/ultralytics/8.3.36 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:1 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:2 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:3 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:4 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:5 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:6 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:7 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train10/weights/best.pt data=config.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        845       1649      0.968      0.964      0.977      0.927      0.965       0.96      0.968      0.896
#           Bottled Soda         37         37      0.986          1      0.995      0.965      0.987          1      0.995      0.942
#                 Cheese         40         58          1       0.98      0.995      0.956          1      0.979      0.995      0.941
#                 Kitkat         42         47      0.996      0.979      0.995      0.956      0.996      0.979      0.995      0.935
# ...

# %%
from PIL import Image
from IPython.display import display

image_path = 'runs/segment/val10/confusion_matrix_normalized.png'

# Open and display the image
image = Image.open(image_path)
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %% [markdown]
# ## Inference test on Trial 10

# %%
# !yolo task=segment mode=predict model=runs/segment/train9/weights/best.pt source=dataset/images/val
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
#
# image 1/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010012.jpg: 640x480 1 Bottled Soda, 61.8ms
# image 2/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010017.jpg: 640x480 1 Bottled Soda, 15.5ms
# image 3/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010033.jpg: 640x480 1 Bottled Soda, 15.1ms
# image 4/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010036.jpg: 640x480 1 Bottled Soda, 15.0ms
# image 5/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010039.jpg: 640x480 1 Bottled Soda, 14.9ms
# image 6/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010065.jpg: 640x480 1 Bottled Soda, 15.1ms
# ...

# %% [markdown]
# ## Epochs: 50

# %%
# !yolo task=segment mode=train model=yolo11x-seg.pt data=config.yaml epochs=50 imgsz=640 mosaic=0.5 hsv_h=0.015 hsv_s=0.7 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=256 device=0,1,2,3,4,5,6,7
# Out:
# New https://pypi.org/project/ultralytics/8.3.36 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:1 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:2 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:3 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:4 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:5 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:6 (NVIDIA A100-SXM4-40GB, 40339MiB)
#                                                        CUDA:7 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train11/weights/best.pt data=config.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        845       1649      0.971      0.965      0.977      0.931      0.969      0.961      0.967      0.901
#           Bottled Soda         37         37      0.992          1      0.995      0.973      0.993          1      0.995      0.954
#                 Cheese         40         58          1      0.941      0.981      0.937          1       0.94      0.981      0.927
#                 Kitkat         42         47          1      0.982      0.995      0.967          1      0.981      0.995      0.949
# ...

# %%
from PIL import Image
from IPython.display import display

image_path = 'runs/segment/val11/confusion_matrix_normalized.png'

# Open and display the image
image = Image.open(image_path)
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %% [markdown]
# ## Inference test on Trial 11

# %%
# !yolo task=segment mode=predict model=runs/segment/train11/weights/best.pt source=dataset/images/val
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
#
# image 1/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010012.jpg: 640x480 1 Bottled Soda, 60.4ms
# image 2/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010017.jpg: 640x480 1 Bottled Soda, 17.0ms
# image 3/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010033.jpg: 640x480 1 Bottled Soda, 15.1ms
# image 4/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010036.jpg: 640x480 1 Bottled Soda, 14.9ms
# image 5/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010039.jpg: 640x480 1 Bottled Soda, 19.2ms
# image 6/845 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010065.jpg: 640x480 1 Bottled Soda, 16.7ms
# ...

# %% [markdown]
# # Trial 12: Run on improved dataset with prior models
#
# With 30 epochs on Trial 11 best model.

# %%
# !yolo task=segment mode=train model=runs/segment/train11/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.015 hsv_s=0.7 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.40 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train12/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %%
from PIL import Image
from IPython.display import display

image_path = 'runs/segment/val12/confusion_matrix_normalized.png'

# Open and display the image
image = Image.open(image_path)
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %% [markdown]
# # Inference Test on Trial 12

# %%
# !yolo task=segment mode=predict model=runs/segment/train12/weights/best.pt source=dataset/images/val
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
#
# image 1/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010012.jpg: 640x480 1 Bottled Soda, 51.8ms
# image 2/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010017.jpg: 640x480 1 Bottled Soda, 16.1ms
# image 3/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010033.jpg: 640x480 1 Bottled Soda, 1 Ketchup, 1 Dove Soap, 15.4ms
# image 4/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010036.jpg: 640x480 1 Bottled Soda, 1 Dove Soap, 15.5ms
# image 5/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010039.jpg: 640x480 1 Bottled Soda, 1 Garlic, 1 Ketchup, 14.9ms
# ...

# %% [markdown]
# # Trial 13
#
# Trial 11 + 50 epoch run.

# %%
# !yolo task=segment mode=train model=runs/segment/train11/weights/best.pt data=config_v3.yaml epochs=50 imgsz=640 mosaic=0.5 hsv_h=0.015 hsv_s=0.7 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.43 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
from ultralytics import YOLO

# Load the YOLO model
model = YOLO('runs/segment/train13/weights/best.pt')

# Export the model to ONNX format
model.export(format='onnx', dynamic=True)
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CPU (AMD EPYC 7742 64-Core Processor)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
#
# PyTorch: starting from 'runs/segment/train13/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 60, 8400), (1, 32, 160, 160)) (119.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 116.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 117.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 4.3s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.43...
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train13/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# ## Inference Test on Trial 13

# %%
# !yolo task=segment mode=predict model=runs/segment/train13/weights/best.pt source=dataset/images/val
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
#
# image 1/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010012.jpg: 640x480 1 Bottled Soda, 52.6ms
# image 2/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010017.jpg: 640x480 1 Bottled Soda, 15.5ms
# image 3/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010033.jpg: 640x480 1 Bottled Soda, 1 Ketchup, 1 Dove Soap, 15.0ms
# image 4/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010036.jpg: 640x480 1 Bottled Soda, 1 Dove Soap, 15.4ms
# image 5/1119 /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/010039.jpg: 640x480 1 Bottled Soda, 1 Garlic, 1 Ketchup, 14.9ms
# ...

# %% [markdown]
# # Trial 14: Add Additional Images to Improve Inference + Trial 11

# %%
# !yolo task=segment mode=train model=runs/segment/train11/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.15 hsv_s=0.7 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.44 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# # Trial 15: HSV_h 0.25

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.25 hsv_s=0.7 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=16 device=0 augment=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.44 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train15/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# # Trial 16: HSV_h 0.35

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.35 hsv_s=0.7 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=16 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.44 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train16/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# # Trial 17: HSV_h 0.45

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.45 hsv_s=0.7 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=16 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.44 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train17/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# # Trial 18: HSV_s 0.6

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.15 hsv_s=0.6 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0 augment=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.44 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train18/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# # Trial 19: HSV_s 0.5

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.15 hsv_s=0.5 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0 augment=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train19/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# # Trial 20: HSV_s 0.4

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.15 hsv_s=0.4 hsv_v=0.4 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0 augment=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train20/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %%
from PIL import Image
from IPython.display import display

image_path = 'runs/segment/val15/confusion_matrix_normalized.png'

# Open and display the image
image = Image.open(image_path)
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %% [markdown]
# # Trial 21: HSV_v 0.5

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.15 hsv_s=0.7 hsv_v=0.5 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0 augment=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train21/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# # Trial 22: HSV_v 0.6

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.15 hsv_s=0.7 hsv_v=0.6 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0 augment=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train22/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# # Trial 23: HSV_v 0.7

# %%
# !yolo task=segment mode=train model=runs/segment/train14/weights/best.pt data=config_v3.yaml epochs=30 imgsz=640 mosaic=0.5 hsv_h=0.15 hsv_s=0.7 hsv_v=0.7 degrees=0.373 translate=0.45 scale=0.5 shear=0.3 flipud=0.01 fliplr=0.5 mixup=0.5 batch=32 device=0 augment=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train23/weights/best.pt data=config_v3.yaml epochs=1 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.15 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# YOLO11x-seg summary (fused): 491 layers, 62,029,848 parameters, 0 gradients, 318.7 GFLOPs
# val: Scanning /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/l
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090354.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090368.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090372.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090373.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /raid/students/juan/train/grocery-item-segmentation-yolo/dataset/images/val/090381.jpg: corrupt JPEG restored and saved
# ...
